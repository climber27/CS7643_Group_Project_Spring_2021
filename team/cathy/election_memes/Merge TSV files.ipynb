# %% [markdown]
# **Combine hateful memes tsv files and election memes tsv files into one set of tsv files for ernie-vil**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/colab/ernie-vil
# Out:
# /content/gdrive/MyDrive/colab/ernie-vil

# %%
# !ls
# Out:
# combined_tsv  election_tsv  hateful_memes_tsv  img

# %%
# !cat hateful_memes_tsv/hm_vgattr3636.tsv election_tsv/hm_vgattr3636.tsv > combined_tsv/hm_vgattr3636.tsv

# %%
# !cat hateful_memes_tsv/hm_vgattr7272.tsv election_tsv/hm_vgattr7272.tsv > combined_tsv/hm_vgattr7272.tsv

# %%
# !cat hateful_memes_tsv/hm_vgattr10100.tsv election_tsv/hm_vgattr10100.tsv > combined_tsv/hm_vgattr10100.tsv

# %%
# !cat hateful_memes_tsv/hm_vg5050.tsv election_tsv/hm_vg5050.tsv > combined_tsv/hm_vg5050.tsv

# %%
# !cat hateful_memes_tsv/hm_vg10100.tsv election_tsv/hm_vg10100.tsv > combined_tsv/hm_vg10100.tsv

# %%
# !ls combined_tsv
# Out:
# hm_vg10100.tsv	hm_vgattr10100.tsv  hm_vgattr7272.tsv
# hm_vg5050.tsv	hm_vgattr3636.tsv
