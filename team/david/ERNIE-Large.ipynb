# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git config --global user.email "EMAIL"
# !git config --global user.name "USERNAME"
# !git config remote.origin.url 'https://{TOKEN}@github.com/{USERNAME}/CS7643_Group_Project_Spring_2021.git'

# %%
# %cd gdrive/MyDrive/CS7643_Group_Project_Spring_2021/data/vilio/ernie-vil/
# Out:
# /content/gdrive/MyDrive/CS7643_Group_Project_Spring_2021

# %%
# !pip install paddlepaddle-gpu==1.8.3.post97
# !pip install json-lines
# !pip install ImageHash

# %%
# !rm -rf detectron.lmdb/

# %%
# !unzip hmfeatureszipfin.zip
# Out:
# Archive:  hmfeatureszipfin.zip
#   inflating: detectron.lmdb/data.mdb
#   inflating: detectron.lmdb/lock.mdb

# %%
import os
os.environ['KAGGLE_USERNAME'] = "KAGGLE USER NAME HERE"
os.environ['KAGGLE_KEY'] = "KAGGLE API KEY HERE"

# %%
# !kaggle datasets download muennighoff/hmfeatureszipfin
# Out:
# Downloading hmfeatureszipfin.zip to /content/gdrive/MyDrive/CS7643_Group_Project_Spring_2021/data/vilio/ernie-vil/data/hm
# 100% 9.57G/9.58G [02:29<00:00, 48.7MB/s]
# 100% 9.58G/9.58G [02:29<00:00, 68.6MB/s]

# %%
# !wget https://dl.fbaipublicfiles.com/pythia/data/imdb/textvqa_0.5.tar.gz
# Out:
# --2021-04-20 14:00:02--  https://dl.fbaipublicfiles.com/pythia/data/imdb/textvqa_0.5.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.75.142, 104.22.74.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.75.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28021510 (27M) [application/gzip]
# Saving to: ‘textvqa_0.5.tar.gz’
#
# textvqa_0.5.tar.gz  100%[===================>]  26.72M  6.70MB/s    in 4.7s
#
# 2021-04-20 14:00:08 (5.67 MB/s) - ‘textvqa_0.5.tar.gz’ saved [28021510/28021510]

# %%
https://www.kaggle.com/muennighoff/hmfeatureszipfin/download

# %%
"""
Trains ERNIE

- Will output and OVERWRITE to ernie-vil/output_hm 
  - if you run Large then Small, Small wil OVERWRITE Large
- Make sure to have all data in the correct place (../ernie-vil/data/hm)
  1) hateful memes original dataset 
    - images as img/
    - 5 JSONL files that come with original hateful memes data
  2) MMF Detectron TextQA LMDB dir
    - Detectron.lmbd/
      - From this command !kaggle datasets download muennighoff/hmfeatureszipfin
      - Setup Kaggle account if you haven't &  create an API key
  3) Actual detectron2 hateful meme features
    - hm_vgattr5050.tsv, etc
    - NOTE: his bash scripts will transform / overwrite this data BUT it
      seems like you only have to put it in there once

NOTES:
- unzip tar files with !tar -xvzf FILENAME.tar.gz
- Make sure you're on a GPU
"""
# !bash bash/training/EL/hm_EL.sh

# %%
# !git push
# Out:
# Counting objects: 19, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (19/19), done.
# Writing objects: 100% (19/19), 18.77 KiB | 768.00 KiB/s, done.
# Total 19 (delta 12), reused 0 (delta 0)
# remote: Resolving deltas: 100% (12/12), completed with 3 local objects.
# remote:
# remote: Create a pull request for 'david_detectron2_extract' on GitHub by visiting:
# remote:      https://github.com/daviddlima/CS7643_Group_Project_Spring_2021/pull/new/david_detectron2_extract
# remote:
# To https://github.com/daviddlima/CS7643_Group_Project_Spring_2021.git
#  * [new branch]      david_detectron2_extract -> david_detectron2_extract
