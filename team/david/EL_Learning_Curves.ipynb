# %%
from IPython.display import clear_output 
from google.colab import drive
import seaborn as sns
import pickle
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/MyDrive/CS7643_Group_Project_Spring_2021/
# Out:
# /content/gdrive/MyDrive/CS7643_Group_Project_Spring_2021

# %%
# !git config --global user.email "dlima.david@gmail.com"
# !git config --global user.name "daviddlima"
# !git config remote.origin.url 'https://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@github.com/daviddlima/CS7643_Group_Project_Spring_2021.git'

# %%
# %cd data/vilio/ernie-vil/
# Out:
# /content/gdrive/My Drive/CS7643_Group_Project_Spring_2021/data/vilio/ernie-vil

# %%
# !pip install paddlepaddle-gpu==1.8.3.post97
# !pip install json-lines
# !pip install ImageHash
clear_output()

# %%
# !bash bash/training/EL/hm_EL.sh | tee ALL_EL_output.log  2>&1
# Out:
# Streaming output truncated to the last 5000 lines.
# used_time: 0.3712117671966553
# feed_queue size 30
# epoch: 0, progress: 0/0, step: 750, loss: 0.616677, acc: 0.375000
# steps: 750
# save_steps: 1250
# 20210429 21:55:33 current learning_rate:0.00001000
# used_time: 0.3786444664001465
# feed_queue size 30
# epoch: 0, progress: 0/0, step: 760, loss: 0.338797, acc: 0.875000
# steps: 760
# save_steps: 1250
# 20210429 21:55:36 current learning_rate:0.00001000
# used_time: 0.35585522651672363
# feed_queue size 30
# epoch: 0, progress: 0/0, step: 770, loss: 1.157261, acc: 0.625000
# steps: 770
# save_steps: 1250
# 20210429 21:55:40 current learning_rate:0.00001000
# used_time: 0.37674975395202637
# feed_queue size 30
# epoch: 0, progress: 0/0, step: 780, loss: 0.342282, acc: 0.500000
# steps: 780
# save_steps: 1250
# 20210429 21:55:44 current learning_rate:0.00001000
# used_time: 0.38812851905822754
# feed_queue size 30
# ...
