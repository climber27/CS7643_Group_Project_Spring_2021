# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/My Drive/OMSCS/DL/FinalProject
# Out:
# /content/gdrive/My Drive/OMSCS/DL/FinalProject
# 'Copy of hm_vgattr10100.tsv'   ERNIE-ViL_Data/
# 'Copy of hm_vgattr3636.tsv'   'Initial Research.gdoc'
# 'Copy of hm_vgattr5050.tsv'    mmf/
# 'Copy of hm_vgattr7272.tsv'    project_proposal.gdoc
#  Detectron2_HM_Feats/          Tyler/
#  EL365072_test_seen_SA.csv
